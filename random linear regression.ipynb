# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy.stats as stats
matplotlib.style.use('ggplot')

# %%
mmi = pd.read_excel(r"F:\Daily Reports\Distance Calculation.xlsx")

# %%
mmi
# Out:
#     Sr. No.                      Registration  \
# 0       369             Shivanand_Kaladagi_T3
# 1       370                       Suresh_K_98
# 2       371                     Sameer._K_T12
# 3       372            Sooraj_Kumar_Yadav_T10
# 4       373             Rajesh_Kumar_Yadav_68
# 5       374             Sangappa_H_Abakari_T8
# 6       375                BAJRANGI_KUMAR_T23
# 7       376                  Sachin_Gadad_T13
# 8       377               Sachin_Kumar_Jha_59
# 9       378                  Navneet_singh_T7
# 10      379                    Ajay_kumar_T11
# 11      380                       Akash_K_109
# 12      381                 SUNIL_BHARATI_T15
# 13      382                     SUSHEEL_K_T17
# 14      383             Jeevan_Kuamr_Yadav_T4
# 15      384                  Manish_Singh_T26
# 16      385            Deepak_Kumar_Thakur_T1
# 17      386  Shridhar_Chandrakant_Badiger_132
# 18      387             Bimlesh_kumar_sah_T21
# ...

# %%
mmi.columns
# Out:
# Index(['Sr. No.', 'Registration', 'Device', 'Start Location', 'End Location',
#        'Max Speed(Km)', 'Driver Details', 'Date', 'Start Time',
#        'Start Location.1', 'Start Odometer', 'End Time', 'End Location.1',
#        'End Odometer', 'Distance (km)', 'Movement Time', 'Stoppage Time',
#        'Idle Time', 'Active Hours', 'Max Speed(Km).1', 'Unnamed: 20', 'ID',
#        'NAME', 'DIST', 'Max Speed(Km).2', 'Unnamed: 25', 'Unnamed: 26', 'ID.1',
#        'NAME.1', 'Max Speed(Km).3', 'Distance (km).1'],
#       dtype='object')

# %%
mmi.plot(kind='scatter',x='Max Speed(Km).3',y='Distance (km).1',figsize=(6,6));

# %%
mmi['Max Speed(Km).3'].corr(mmi['Distance (km).1'])
# Out:
# 0.2207668010207621
